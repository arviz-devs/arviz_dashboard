# %%
import panel as pn
import pandas as pd
import numpy as np

# %%
pn.extension()

# %%
from arviz_dashboard import get_streaming_components

# %%
pane, stream = get_streaming_components(
    pd.DataFrame(
        {"draw": np.array([]), "x": np.array([], dtype=float)}
    ),
    y="x"
)

# %%
pane
# Out:
# Streamz(map, always_watch=True)

# %%
for i in range(1000):
    stream.emit(pd.DataFrame(
        {"draw": [i], "x": np.random.randn(1)}
    ))
