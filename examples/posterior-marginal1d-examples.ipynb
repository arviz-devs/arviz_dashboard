# %%
import arviz as az
import panel as pn

from arviz_dashboard.marginal.one_d import posterior_marginal1d_dashboard


pn.extension()
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %% [markdown]
# ## `centered_eight`

# %%
posterior_marginal1d_dashboard(az.load_arviz_data("centered_eight"))
# Out:
# Row
#     [0] Column(margin=5, name='PosteriorMarginal1dDashbo..., width=300)
#         [0] StaticText(value='<b>PosteriorMarginal1dDas...)
#         [1] Select(name='Random variable', options=OrderedDict([('mu', ...]), value='mu')
#         [2] MultiSelect(name='Chain selector', options=OrderedDict([('0', ...]), value=[0])
#         [3] Select(name='School selector', options=OrderedDict([('Choate', ...]), value='Choate')
#         [4] Select(name='Chain aggregation', options=OrderedDict([('separate', ...]), value='separate')
#     [1] ParamMethod(method, _pane=Bokeh)

# %% [markdown]
# ## `non_centered_eight`

# %%
posterior_marginal1d_dashboard(az.load_arviz_data("non_centered_eight"))
# Out:
# Row
#     [0] Column(margin=5, name='PosteriorMarginal1dDashbo..., width=300)
#         [0] StaticText(value='<b>PosteriorMarginal1dDas...)
#         [1] Select(name='Random variable', options=OrderedDict([('mu', ...]), value='mu')
#         [2] MultiSelect(name='Chain selector', options=OrderedDict([('0', ...]), value=[0])
#         [3] Select(name='School selector', options=OrderedDict([('Choate', ...]), value='Choate')
#         [4] Select(name='Chain aggregation', options=OrderedDict([('separate', ...]), value='separate')
#     [1] ParamMethod(method, _pane=Bokeh)

# %% [markdown]
# ## `radon`

# %%
posterior_marginal1d_dashboard(az.load_arviz_data("radon"))
# Out:
# Row
#     [0] Column(margin=5, name='PosteriorMarginal1dDashbo..., width=300)
#         [0] StaticText(value='<b>PosteriorMarginal1dDas...)
#         [1] Select(name='Random variable', options=OrderedDict([('g', ...]), value='g')
#         [2] MultiSelect(name='Chain selector', options=OrderedDict([('0', ...]), value=[0])
#         [3] Select(name='G coef selector', options=OrderedDict([('intercept',...]), value='intercept')
#         [4] Select(name='County selector', options=OrderedDict([('AITKIN', ...]), value='AITKIN')
#         [5] Select(name='Chain aggregation', options=OrderedDict([('separate', ...]), value='separate')
#     [1] ParamMethod(method, _pane=Bokeh)

# %% [markdown]
# ## `rugby`

# %%
posterior_marginal1d_dashboard(az.load_arviz_data("rugby"))
# Out:
# Row
#     [0] Column(margin=5, name='PosteriorMarginal1dDashbo..., width=300)
#         [0] StaticText(value='<b>PosteriorMarginal1dDas...)
#         [1] Select(name='Random variable', options=OrderedDict([('home', ...]), value='home')
#         [2] MultiSelect(name='Chain selector', options=OrderedDict([('0', ...]), value=[0])
#         [3] Select(name='Team selector', options=OrderedDict([('Wales', ...]), value='Wales')
#         [4] Select(name='Chain aggregation', options=OrderedDict([('separate', ...]), value='separate')
#     [1] ParamMethod(method, _pane=Bokeh)

# %% [markdown]
# ## `regression1d`

# %%
posterior_marginal1d_dashboard(az.load_arviz_data("regression1d"))
# Out:
# Row
#     [0] Column(margin=5, name='PosteriorMarginal1dDashbo..., width=300)
#         [0] StaticText(value='<b>PosteriorMarginal1dDas...)
#         [1] Select(name='Random variable', options=OrderedDict([('slope', ...]), value='slope')
#         [2] MultiSelect(name='Chain selector', options=OrderedDict([('0', ...]), value=[0])
#         [3] Select(name='Chain aggregation', options=OrderedDict([('separate', ...]), value='separate')
#     [1] ParamMethod(method, _pane=Bokeh)

# %% [markdown]
# ## `regression10d`

# %%
posterior_marginal1d_dashboard(az.load_arviz_data("regression10d"))
# Out:
# Row
#     [0] Column(margin=5, name='PosteriorMarginal1dDashbo..., width=300)
#         [0] StaticText(value='<b>PosteriorMarginal1dDas...)
#         [1] Select(name='Random variable', options=OrderedDict([('w', ...]), value='w')
#         [2] MultiSelect(name='Chain selector', options=OrderedDict([('0', ...]), value=[0])
#         [3] Select(name='W dim 0 selector', options=OrderedDict([('0', ...]), value=0)
#         [4] Select(name='True w dim 0 selector', options=OrderedDict([('0', ...]), value=0)
#         [5] Select(name='Chain aggregation', options=OrderedDict([('separate', ...]), value='separate')
#     [1] ParamMethod(method, _pane=Bokeh)

# %% [markdown]
# ## `classification1d`

# %%
posterior_marginal1d_dashboard(az.load_arviz_data("classification1d"))
# Out:
# Row
#     [0] Column(margin=5, name='PosteriorMarginal1dDashbo..., width=300)
#         [0] StaticText(value='<b>PosteriorMarginal1dDas...)
#         [1] Select(name='Random variable', options=OrderedDict([('slope', ...]), value='slope')
#         [2] MultiSelect(name='Chain selector', options=OrderedDict([('0', ...]), value=[0])
#         [3] Select(name='Y dim 0 selector', options=OrderedDict([('0', ...]), value=0)
#         [4] Select(name='Chain aggregation', options=OrderedDict([('separate', ...]), value='separate')
#     [1] ParamMethod(method, _pane=Bokeh)

# %% [markdown]
# ## `classification10d`

# %%
posterior_marginal1d_dashboard(az.load_arviz_data("classification10d"))
# Out:
# Row
#     [0] Column(margin=5, name='PosteriorMarginal1dDashbo..., width=300)
#         [0] StaticText(value='<b>PosteriorMarginal1dDas...)
#         [1] Select(name='Random variable', options=OrderedDict([('w', ...]), value='w')
#         [2] MultiSelect(name='Chain selector', options=OrderedDict([('0', ...]), value=[0])
#         [3] Select(name='W dim 0 selector', options=OrderedDict([('0', ...]), value=0)
#         [4] Select(name='True w dim 0 selector', options=OrderedDict([('0', ...]), value=0)
#         [5] Select(name='Chain aggregation', options=OrderedDict([('separate', ...]), value='separate')
#     [1] ParamMethod(method, _pane=Bokeh)

# %% [markdown]
# ## `glycan_torsion_angles`

# %%
posterior_marginal1d_dashboard(az.load_arviz_data("glycan_torsion_angles"))
# Out:
# Row
#     [0] Column(margin=5, name='PosteriorMarginal1dDashbo..., width=300)
#         [0] StaticText(value='<b>PosteriorMarginal1dDas...)
#         [1] Select(name='Random variable', options=OrderedDict([('alpha', ...]), value='alpha')
#         [2] MultiSelect(name='Chain selector', options=OrderedDict([('0', 0)]), value=[0])
#         [3] Select(name='Tors dim 0 selector', options=OrderedDict([('0', ...]), value=0)
#         [4] Select(name='Cs mu dim 0 selector', options=OrderedDict([('0', ...]), value=0)
#         [5] Select(name='Chain aggregation', options=OrderedDict([('separate', ...]), value='separate')
#     [1] ParamMethod(method, _pane=Bokeh)
